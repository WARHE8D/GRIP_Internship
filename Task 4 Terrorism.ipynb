# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:/Users/SALMAN/Desktop/GRIP/globalterrorismdb_0718dist.csv',encoding='latin1')
df
# Out:
# C:\Users\SALMAN\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
#import matplotlib.pyplot as plt
#plt.figure(figsize=(40,40))
#sns.heatmap(df.corr(),cmap='binary',linewidths=0.2)

# %%
df=df.drop(['eventid','approxdate','extended','resolution','summary','crit1','crit2','crit3','doubtterr','multiple','attacktype2','attacktype2_txt'],axis=1)

# %%
df=df.drop(['attacktype3_txt','attacktype3','targtype1','targtype1_txt','targsubtype1','targsubtype1_txt','corp1','target1','natlty1','natlty1_txt','targtype2','targtype2_txt','targsubtype2_txt','targsubtype2','corp2','target2','natlty2','natlty2_txt','targtype3','targtype3_txt','targsubtype3','targsubtype3_txt','corp3','target3','natlty3','natlty3_txt'],axis=1)

# %%
df=df.drop(['gname','gsubname','gsubname2','gsubname3','gname2','gname3','individual','nperps','nperpcap','claimed','claimmode','claimmode_txt','claim2','claimmode2','claimmode2_txt','claim3','claimmode3','claimmode3_txt','compclaim'],axis=1)

# %%
df=df.drop(['propextent','propextent_txt','propvalue','propcomment','ishostkid','nhostkid','nhostkidus','nhours','ndays','divert','kidhijcountry'],axis=1)

# %%
df=df.drop(['ransomamt','ransomamtus','ransompaid','ransompaidus','ransomnote','hostkidoutcome','hostkidoutcome_txt','nreleased','addnotes','scite1','scite2','scite3','dbsource'],axis=1)

# %%
df=df.drop(['related'],axis=1)

# %%
df
# Out:
#         iyear  imonth  iday  country         country_txt  region  \
# 0        1970       7     2       58  Dominican Republic       2
# 1        1970       0     0      130              Mexico       1
# 2        1970       1     0      160         Philippines       5
# 3        1970       1     0       78              Greece       8
# 4        1970       1     0      101               Japan       4
# ...       ...     ...   ...      ...                 ...     ...
# 181686   2017      12    31      182             Somalia      11
# 181687   2017      12    31      200               Syria      10
# 181688   2017      12    31      160         Philippines       5
# 181689   2017      12    31       92               India       6
# 181690   2017      12    31      160         Philippines       5
#
#                          region_txt        provstate           city  \
# 0       Central America & Caribbean              NaN  Santo Domingo
# ...

# %%
df['to_guns']=df['guncertain1']+df['guncertain2']+df['guncertain3']
df['to_guns'].value_counts()
df=df.drop(['guncertain1','guncertain2','guncertain3'],axis=1)

# %%
df=df.drop(['imonth','iday'],axis=1)

# %%
#Le motive

# %%
df
# Out:
#         iyear  country         country_txt  region  \
# 0        1970       58  Dominican Republic       2
# 1        1970      130              Mexico       1
# 2        1970      160         Philippines       5
# 3        1970       78              Greece       8
# 4        1970      101               Japan       4
# ...       ...      ...                 ...     ...
# 181686   2017      182             Somalia      11
# 181687   2017      200               Syria      10
# 181688   2017      160         Philippines       5
# 181689   2017       92               India       6
# 181690   2017      160         Philippines       5
#
#                          region_txt        provstate           city  \
# 0       Central America & Caribbean              NaN  Santo Domingo
# 1                     North America          Federal    Mexico city
# 2                    Southeast Asia           Tarlac        Unknown
# 3                    Western Europe           Attica         Athens
# ...

# %%
df=df.drop(['motive'],axis=1)

# %%
df.head()
# Out:
#    iyear  country         country_txt  region                   region_txt  \
# 0   1970       58  Dominican Republic       2  Central America & Caribbean
# 1   1970      130              Mexico       1                North America
# 2   1970      160         Philippines       5               Southeast Asia
# 3   1970       78              Greece       8               Western Europe
# 4   1970      101               Japan       4                    East Asia
#
#   provstate           city   latitude   longitude  specificity  ...  nwound  \
# 0       NaN  Santo Domingo  18.456792  -69.951164          1.0  ...     0.0
# 1   Federal    Mexico city  19.371887  -99.086624          1.0  ...     0.0
# 2    Tarlac        Unknown  15.478598  120.599741          4.0  ...     0.0
# 3    Attica         Athens  37.997490   23.762728          1.0  ...     NaN
# 4   Fukouka        Fukouka  33.580412  130.396361          1.0  ...     NaN
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (30,15))
#matrix = np.triu(df.corr())
sns.heatmap(df.corr(),cmap='binary',linewidths=0.2 ,annot=True)#mask=matrix)

# %%
#weapon type 4 had the most wound rate

# %%
plt.figure(figsize = (16,16))
plt.subplots_adjust(hspace=0.3) #bigger the value bigger the diffrence bw the yaxis
plt.subplots_adjust(wspace=0.3)
plt.subplot(2,2,1)
sns.countplot(df['weaptype1'])
plt.subplot(2,2,2)
sns.countplot(df['weaptype2'])
plt.subplot(2,2,3)
sns.countplot(df['weaptype3'])
plt.subplot(2,2,4)
sns.countplot(df['weaptype4'])

# %%
plt.figure(figsize = (30,16))
plt.subplots_adjust(hspace=0.3) #bigger the value bigger the diffrence bw the yaxis
plt.subplots_adjust(wspace=0.3)
plt.subplot(2,2,1)
sns.countplot(df['weapsubtype1'])
plt.subplot(2,2,2)
sns.countplot(df['weapsubtype2'])
plt.subplot(2,2,3)
sns.countplot(df['weapsubtype3'])
plt.subplot(2,2,4)
sns.countplot(df['weapsubtype4'])

# %%
df['region'].value_counts()
# Out:
# 10    50474
# 6     44974
# 3     18978
# 11    17550
# 8     16639
# 5     12485
# 2     10344
# 9      5144
# 1      3456
# 4       802
# 7       563
# 12      282
# Name: region, dtype: int64

# %%
df['success'].value_counts()
# Out:
# 1    161632
# 0     20059
# Name: success, dtype: int64

# %%
hotzone_region=df[['region','region_txt']][df['success']==1]

# %%
plt.figure(figsize = (10,8))
sns.countplot(hotzone_region['region'],data=hotzone_region,hue="region_txt")

# %%
df.city.value_counts()
# Out:
# Unknown           9775
# Baghdad           7589
# Karachi           2652
# Lima              2359
# Mosul             2265
#                   ...
# Arginoi              1
# Beka'ot              1
# Ban Ton Makham       1
# Webster              1
# Ccocha               1
# Name: city, Length: 36674, dtype: int64
