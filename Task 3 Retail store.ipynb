# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:/Users/SALMAN/Desktop/GRIP/SampleSuperstore.csv')

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#Loss info

df.sort_values(['Profit'],ascending=True,inplace=True)
df.head(20)
# Out:
#            Ship Mode      Segment        Country          City  \
# 7772  Standard Class     Consumer  United States     Lancaster
# 683         Same Day    Corporate  United States    Burlington
# 9774  Standard Class     Consumer  United States   San Antonio
# 3011  Standard Class  Home Office  United States    Louisville
# 4991  Standard Class    Corporate  United States       Chicago
# 3151     First Class     Consumer  United States        Newark
# 5310     First Class     Consumer  United States       Houston
# 9639    Second Class     Consumer  United States       Concord
# 1199  Standard Class     Consumer  United States       Houston
# 2697  Standard Class  Home Office  United States  Jacksonville
# 27    Standard Class     Consumer  United States  Philadelphia
# 3324  Standard Class     Consumer  United States       Houston
# 165   Standard Class     Consumer  United States   San Antonio
# 2928  Standard Class  Home Office  United States    Burlington
# ...

# %%
#Profit info
df.sort_values(['Profit'],ascending=False,inplace=True)
df.head(20)
# Out:
#            Ship Mode      Segment        Country             City  \
# 6826  Standard Class    Corporate  United States        Lafayette
# 8153     First Class     Consumer  United States          Seattle
# 4190  Standard Class     Consumer  United States           Newark
# 9039  Standard Class     Consumer  United States          Detroit
# 4098  Standard Class     Consumer  United States      Minneapolis
# 2623     First Class  Home Office  United States    New York City
# 509   Standard Class     Consumer  United States          Atlanta
# 8488    Second Class     Consumer  United States        Arlington
# 7666  Standard Class  Home Office  United States       Providence
# 6520    Second Class     Consumer  United States          Jackson
# 1085  Standard Class     Consumer  United States          Yonkers
# 4277  Standard Class    Corporate  United States         Lakewood
# 8990  Standard Class    Corporate  United States      Springfield
# ...

# %%
#slicing profit and loss
df['P/L']=pd.cut(df['Profit'],bins=[-6700,0,4000,9000],labels=['Loss','NPNL','Profit'])

# %%
df
# Out:
#            Ship Mode      Segment        Country         City           State  \
# 6826  Standard Class    Corporate  United States    Lafayette         Indiana
# 8153     First Class     Consumer  United States      Seattle      Washington
# 4190  Standard Class     Consumer  United States       Newark        Delaware
# 9039  Standard Class     Consumer  United States      Detroit        Michigan
# 4098  Standard Class     Consumer  United States  Minneapolis       Minnesota
# ...              ...          ...            ...          ...             ...
# 4991  Standard Class    Corporate  United States      Chicago        Illinois
# 3011  Standard Class  Home Office  United States   Louisville        Colorado
# 9774  Standard Class     Consumer  United States  San Antonio           Texas
# 683         Same Day    Corporate  United States   Burlington  North Carolina
# 7772  Standard Class     Consumer  United States    Lancaster            Ohio
#
# ...

# %%
import seaborn as sns

# %%
sns.countplot(df['P/L'])

# %%
df['P/L'].value_counts()
# Out:
# NPNL      8053
# Loss      1936
# Profit       5
# Name: P/L, dtype: int64

# %%
#seperated loss 
loss=df[df['P/L']=='Loss']

# %%
#seperated Profit
profit=df[df['P/L']=='Profit']

# %%
print(loss.nunique())
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             241
# State             30
# Postal Code      281
# Region             4
# Category           3
# Sub-Category      12
# Sales           1574
# Quantity          14
# Discount          12
# Profit          1643
# P/L                1
# dtype: int64

# %%
print(profit.nunique())
# Out:
# Ship Mode       2
# Segment         2
# Country         1
# City            5
# State           5
# Postal Code     5
# Region          3
# Category        2
# Sub-Category    2
# Sales           5
# Quantity        4
# Discount        1
# Profit          5
# P/L             1
# dtype: int64

# %%
#I chose cities because there was a major difference between the P/L 
#and sub categoris etc didnt had much impact on p/l
loss['City'].value_counts()
# Out:
# Philadelphia    254
# Houston         187
# Chicago         157
# Dallas           73
# Columbus         51
#                ...
# Deltona           1
# Anaheim           1
# Chico             1
# Mobile            1
# Littleton         1
# Name: City, Length: 241, dtype: int64

# %%
profit['City'].value_counts()
# Out:
# Minneapolis    1
# Seattle        1
# Detroit        1
# Lafayette      1
# Newark         1
# Name: City, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=loss['City'].value_counts()
x=x.head()

# %%
explode = (0.1, 0, 0, 0,0)
plt.pie(x,explode=explode,labels=['Philadelphia','Houston','Chicago','Dallas','Columbus'],shadow=True)
plt.show()

#this shows that Philadelphia,Houston,Chicago,Dallas,Columbus has the most loss in the market

# %%
profit
# Out:
#            Ship Mode    Segment        Country         City       State  \
# 6826  Standard Class  Corporate  United States    Lafayette     Indiana
# 8153     First Class   Consumer  United States      Seattle  Washington
# 4190  Standard Class   Consumer  United States       Newark    Delaware
# 9039  Standard Class   Consumer  United States      Detroit    Michigan
# 4098  Standard Class   Consumer  United States  Minneapolis   Minnesota
#
#       Postal Code   Region         Category Sub-Category     Sales  Quantity  \
# 6826        47905  Central       Technology      Copiers  17499.95         5
# 8153        98115     West       Technology      Copiers  13999.96         4
# 4190        19711     East       Technology      Copiers  10499.97         3
# 9039        48205  Central  Office Supplies      Binders   9892.74        13
# 4098        55407  Central  Office Supplies      Binders   9449.95         5
#
#       Discount     Profit     P/L
# 6826       0.0  8399.9760  Profit
# ...

# %%
df[df['P/L']=='NPNL']
# Out:
#            Ship Mode      Segment        Country           City         State  \
# 2623     First Class  Home Office  United States  New York City      New York
# 509   Standard Class     Consumer  United States        Atlanta       Georgia
# 8488    Second Class     Consumer  United States      Arlington      Virginia
# 7666  Standard Class  Home Office  United States     Providence  Rhode Island
# 6520    Second Class     Consumer  United States        Jackson      Michigan
# ...              ...          ...            ...            ...           ...
# 8574        Same Day  Home Office  United States  San Francisco    California
# 9859  Standard Class  Home Office  United States       Richmond       Indiana
# 3565     First Class     Consumer  United States    Los Angeles    California
# 9875  Standard Class     Consumer  United States  New York City      New York
# 3843     First Class    Corporate  United States    Los Angeles    California
#
# ...

# %%
corelation=df[['Sales','Quantity','Discount','Profit']]
corelation
# Out:
#           Sales  Quantity  Discount     Profit
# 6826  17499.950         5       0.0  8399.9760
# 8153  13999.960         4       0.0  6719.9808
# 4190  10499.970         3       0.0  5039.9856
# 9039   9892.740        13       0.0  4946.3700
# 4098   9449.950         5       0.0  4630.4755
# ...         ...       ...       ...        ...
# 4991   1889.990         5       0.8 -2929.4845
# 3011   2549.985         5       0.7 -3399.9800
# 9774   2177.584         8       0.8 -3701.8928
# 683    7999.980         4       0.5 -3839.9904
# 7772   4499.985         5       0.7 -6599.9780
#
# [9994 rows x 4 columns]

# %%
sns.heatmap(corelation.corr())
#here profit and sales are coorelated 
#and discount and profit are highly not coorelated
